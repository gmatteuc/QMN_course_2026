# %% [markdown]
# # Notebook 1 — Programming & Python Fundamentals
#
# *Quantitative Methods in Neuroscience, Master in Neuroscience, University of Geneva (2026-27)*
#
# Welcome to the very first hands-on session of the course! This notebook walks you through the **Python building blocks** that every subsequent practical will rely on. By the end of it you should feel comfortable opening a notebook, typing some code, running it, reading errors, and putting together a small piece of Python from scratch.
#
# > If you have never installed Python before, follow `SETUP_INSTRUCTIONS.txt` at the root of the course folder first. Make sure the `qmn` conda environment is created and selected as the kernel of this notebook (top-right corner of VS Code). The TAs will walk through the install.
#
# ### By the end of this notebook you will be able to:
# - Navigate a Jupyter notebook (cells, kernel, shortcuts).
# - Use **variables**, **basic types**, and **arithmetic**.
# - Use **lists**, **tuples**, **dictionaries** and **f-string** formatting.
# - Write **conditionals** (`if`/`elif`/`else`) and **loops** (`for`/`while`).
# - Recognise a Python **function call** and explain what its inputs and outputs mean.
# - **Import** modules and use the built-in help.
# - Read a Python **error traceback** and understand what it says.
# - Apply all of the above to a small first analysis on a real-world-style behavioural dataset.
#
# ### Table of contents
# 1. [How to use this notebook](#section-1)
# 2. [Jupyter mechanics](#section-2)
# 3. [Variables, basic types and functions](#section-3)
# 4. [Arithmetic, strings and printing](#section-4)
# 5. [Collections: lists, tuples, dictionaries](#section-5)
# 6. [Conditionals](#section-6)
# 7. [Loops](#section-7)
# 8. [Imports and the standard library](#section-8)
# 9. [Reading errors and asking for help](#section-9)
# 10. [VS Code as your IDE — quick orientation](#section-10)
# 11. [Bridge exercise: a first peek at the course dataset](#section-11)
#
# > **How to read this notebook.** Markdown cells like this one explain the *concept*. Code cells implement it. Look out for **`▶ Task`** boxes: those are short exercises where you have to edit or extend the code. If you get stuck, ask the TAs. If you use AI help, treat it as a tutor, not as a replacement for thinking: you should still be able to read each line of code and explain what it does. We have prepared a custom GPT bot tuned for this course: https://chatgpt.com/g/g-69fc9bfc9a748191a912a124800d9254-qmn-teaching-assistant-bot

# %% [markdown]
# ## A 2-minute warm-up — what is programming?
#
# If you have never written a line of code before, breathe: this notebook is built exactly for you. Two ideas in plain language before we start.
#
# - **A computer is a very fast, very literal "employee".** It does exactly what you tell it to do, in exactly the order you tell it, and stops at the first thing it does not understand. "Programming" is the act of *writing down* instructions for that employee.
# - **Python is a language for those instructions**, chosen here because its rules (i.e. syntax) are concise, its scientific libraries are excellent, and most neuroscience labs use it day-to-day. You will not need to *memorize* all of this immediatly: you will pick them up by reading code, modifying it, and seeing what changes.
#
# A **Jupyter notebook** (the file you are reading) is a sequence of *cells*. Some cells, like this one, contain **text**. Others contain **Python code** that you can run by clicking on the cell and pressing `Shift+Enter`. You will see your first runnable code cell in a moment.

# %% [markdown]
# <a id="section-1"></a>
# ## 1. How to use this notebook
#
# Each section introduces one Python building block, then asks you to use it on a small problem. The recipe is always the same:
#
# 1. **Read** the markdown cell that explains the concept.
# 2. **Run** the code cell (`Shift+Enter`) and look at the output.
# 3. **Tweak** the code: change a value, add a `print`, see what changes.
# 4. **Do the `▶ Task`** at the end of the section by editing the `# TODO` cell.
#
# Don't be afraid to break things in this notebook, that is *how* you learn.
#
# > **Note.** This notebook is deliberately shallow but wide: we touch on each concept just enough to be able to *read* and *modify* the code in the following notebooks (Math Refresher, Statistics, …). We will revisit each topic in greater depth when we need it. For more resousces on Python see the relevant section of the course materials page.

# %% [markdown]
# <a id="section-2"></a>
# ## 2. Jupyter mechanics
#
# A Jupyter notebook (the type of file you are reading) is a sequence of **cells** of two kinds:
#
# - **Markdown cells** (like this one) contain *text*. They are rendered into nicely formatted prose, lists, tables, equations, etc. Double-click on a markdown cell to edit it, then `Shift+Enter` to render.
# - **Code cells** contain *Python code*. `Shift+Enter` runs the cell; whatever it produces (numbers, plots, errors) appears just below.
#
# Behind the scenes, a **kernel** (the small Python process attached to the notebook) keeps the variables you define alive across cells. So a variable created in one cell can be reused in a later cell. **This means the *order* in which you run cells matters.** If something looks wrong, the safe move is *Kernel → Restart Kernel and Run All*: it gives you a fresh slate and re-runs every cell in order.
#
# Run the next cell: it should print a message and show that things are alive.

# %%
# --- A first code cell. Pressing Shift+Enter on this cell runs it.
print("Hello, QMN! Your kernel is alive.")
2 + 2  # The last expression of a cell is automatically displayed below.

# %% [markdown]
# > **▶ Task 2.1 — Make yourself at home.**
# > 1. Edit the markdown cell below to introduce yourself in three bullet points (name, background, one neuroscience topic that fascinates you). Use `**bold**` for your name and `*italics*` somewhere.
# > 2. Insert a brand-new code cell *below* the markdown cell (`Esc`, then `B`), and use it to print the result of `7 * 6`.

# %% [markdown]
# *Replace this text with your three bullet points.*

# %% [markdown]
# <a id="section-3"></a>
# ## 3. Variables, basic types and functions
#
# A **variable** is a *name* you give to a *value*, so you can reuse the value later in your code. Think of it as a labelled box: the **label** is the name (on the left of `=`), and the **box** holds the value (on the right of `=`).
#
# Let's create the simplest variable possible: a counter that holds the number `240`.

# %%
# --- Our very first variable
n_trials = 240    # the value 240 is assigned to the name "n_trials"
print(n_trials)   # later we can ask Python to print whatever n_trials currently holds

# %% [markdown]
# So far we used an integer (`240`). But a variable can hold many other kinds of values: decimal numbers, text, truth values, or "nothing" (a placeholder). The kind of value is called the **type**. You can ask Python what type a value has with the built-in `type()` function. Let's create a variable of each common type and inspect it:

# %%
# --- Some variables of different types
n_subjects = 12             # int
mean_rt    = 0.485          # float
subject_id = "S01"          # str
is_correct = True           # bool
not_set    = None           # NoneType

print(n_subjects, type(n_subjects))
print(mean_rt,    type(mean_rt))
print(subject_id, type(subject_id))
print(is_correct, type(is_correct))
print(not_set,    type(not_set))

# %% [markdown]
# **Reference: the basic types you'll meet in this course:**
#
# | Type        | Example             | Represents                |
# |-------------|---------------------|---------------------------|
# | `int`       | `12`                | integer numbers           |
# | `float`     | `3.14`              | real numbers (decimal)    |
# | `str`       | `"hello"`           | text (a "string")         |
# | `bool`      | `True` / `False`    | truth values              |
# | `NoneType`  | `None`              | "nothing here yet"        |
#
# **Naming conventions.** Use **descriptive** names in `snake_case` (lowercase words separated by underscores): `mean_rt`, `n_trials`, `subject_id`. The name of a veraiable should ideally tell somthing about its meaning (this will make your code more readable by you and others). Avoid single letters except for short throwaway counters like `i`, `j`. I's alos good pratice to comment the code you write describing in words whatz each line does (after a `#` symbol in Python).

# %% [markdown]
# You can **reassign** a variable at any time: Python does not care what type the new value has:

# %%
# --- A variable can be reassigned (and its type can even change)
x = 10 # after this line, x holds the integer value 10
print(x, type(x)) # print the value and type of x
x = "ten" # after this line, x holds the string value "ten"
print(x, type(x)) # print the value and type of x again (notice how it changed)

# %% [markdown]
# > **▶ Task 3.1 — Declare and print.**
# > Create three variables of your choice (one of each: `int`, `float`, `str`), and print each one followed by its type, in this format:
# >
# > ```text
# > value = 42  (int)
# > ```

# %%
# TODO 3.1 — your code here
my_int   = 42                       # TO BE REMOVED
my_float = 3.14                     # TO BE REMOVED
my_str   = "neuron"                 # TO BE REMOVED

print(f"value = {my_int}  ({type(my_int).__name__})")
print(f"value = {my_float}  ({type(my_float).__name__})")
print(f"value = {my_str}  ({type(my_str).__name__})")
type(my_int)

# %% [markdown]
# Notice that `type()` is the first instance of Python "function" that we encounter: if we give any variable to it as *input* it will return (i.e. give back) the information about the type of that variable.
#
# Remember that in general a **function** is a reusable piece of code that takes some inputs and returns an output ***function_name(inputs) = outputs***.
#
# We will see in greater depth how functions work and how you can define your own functions further in this course.

# %% [markdown]
# <a id="section-4"></a>
# ## 4. Arithmetic, strings and printing
#
# ### 4.1 Arithmetic operators
#
# The simplest thing you can do in Python is treat it as a calculator. Try the cell below: each line is one calculation, and Python prints the result.

# %%
# --- A quick numerical playground
print(3 + 4)
print(7 / 2)
print(7 // 2)
print(7 % 2)
print(2 ** 10)
print(2 * (3 + 4))

# %% [markdown]
# **Reference — arithmetic operators:**
#
# | Symbol | Operation         | Example               |
# |--------|-------------------|-----------------------|
# | `+`    | addition          | `3 + 4 → 7`           |
# | `-`    | subtraction       | `3 - 4 → -1`          |
# | `*`    | multiplication    | `3 * 4 → 12`          |
# | `/`    | division          | `7 / 2 → 3.5`         |
# | `//`   | integer division  | `7 // 2 → 3`          |
# | `%`    | modulo (remainder) | `7 % 2 → 1`          |
# | `**`   | exponent          | `2 ** 10 → 1024`      |
#
# Parentheses work as in mathematics: `2 * (3 + 4)` is `14`, while `2 * 3 + 4` is `10` (operator precednce is the same as you lern in school for mathematical operators).

# %% [markdown]
# ### 4.2 Strings and f-strings
#
# A **string** is a sequence of characters surrounded by quotes (single `'…'` or double `"…"`, both work; pick one and stay consistent).
#
# The single most useful tool for *combining text with values* is the **f-string**: a string prefixed with `f` in which any `{expression}` inside braces is replaced by the value of that expression. You will use f-strings constantly:

# %%
# --- f-strings
subject = "S01"
n_trials = 1440
mean_rt  = 0.4853

# Anything inside {...} inside an f-string is replaced by its value:
print(f"Subject {subject} ran {n_trials} trials with mean RT {mean_rt:.3f} s.")

# The :.3f after mean_rt means "format as a float with 3 decimals".
# Other useful format specifiers:
print(f"{mean_rt:.0f}")     # round to nearest integer
print(f"{mean_rt * 100:.1f}%")  # percentage, 1 decimal
print(f"{n_trials:,}")      # thousands separator

# %% [markdown]
# > **▶ Task 4.1 — A small calculation.**
# > A behavioural experiment has 8 sessions of 45 minutes each, and on average the subject completes 1 trial every 3 seconds. Use Python expressions to compute and print, with f-strings:
# > 1. Total number of trials across all sessions.
# > 2. Number of trials per minute (rounded to one decimal).
# > 3. Average duration of one session in hours (rounded to two decimals).

# %%
# TODO 4.1 — your code here
n_sessions       = 8
minutes_per_session = 45
seconds_per_trial   = 3

trials_per_minute = 60 / seconds_per_trial                        # TO BE REMOVED
trials_total      = n_sessions * minutes_per_session * trials_per_minute  # TO BE REMOVED
hours_per_session = minutes_per_session / 60                      # TO BE REMOVED

print(f"Total trials:           {trials_total:,.0f}")
print(f"Trials per minute:      {trials_per_minute:.1f}")
print(f"Session duration (h):   {hours_per_session:.2f}")

# %% [markdown]
# <a id="section-5"></a>
# ## 5. Collections: lists, tuples, dictionaries
#
# Real data are rarely a single number: you usually have *many* of them, often labelled. Python ships with three workhorse containers.
#
# ### 5.1 Lists
#
# A **list** is an ordered, mutable (= modifiable) collection of values. You write it with **square brackets** and commas. Lists can contain anything, even values of different types.

# %%
# --- Lists
subjects = ["S01", "S02", "S03"]
rts      = [0.41, 0.55, 0.62, 0.39, 0.48]

print(subjects)
print("length:", len(subjects))          # number of elements
print("first :", subjects[0])            # indexing is 0-based!
print("last  :", subjects[-1])           # negative index = from the end
print("slice :", rts[1:4])               # elements 1, 2, 3 (4 excluded)

# %% [markdown]
# ### 5.2 Methods and attributes
#
# In Python, everything is an **object**: a number, a string, a list, a dictionary *everything* (Python is an Object Oriented language). You can think of every object like an object in real life: it can be able to "do something" (*methods*) and it can "have some properies" (*attributes*). Each object comes with two kinds of "tools" that you access through a `.` (the **dot operator**):
#
# - **Methods** are *functions that belong to the object*. You call them *with* parentheses: `object.method_name(arguments)`.
# - **Attributes** are *pieces of data stored inside the object*. You read them *without* parentheses: `object.attribute_name`.
#
# This is the minimum "object-oriented programming" vocabulary you need to get through the rest of the course. You will see the ***object.something()*** pattern everywhere, especially from next week onwards when we meet `pandas` (`df.head()`, `df.groupby(...)`) and `numpy` (`array.mean()`, `array.shape`).
#
# Let's start with **list methods**. A list comes with a small toolbox for modifying itself *in place*:

# %%
# --- List methods: modifying a list in place
subjects = ["S01", "S02", "S03"]
print("start    :", subjects)

subjects.append("S04")                  # add an element at the end
print("append   :", subjects)

last = subjects.pop()                   # remove AND return the last element
print("pop      :", subjects, "→ removed:", last)

subjects.insert(1, "S00")               # insert at a given position
print("insert   :", subjects)

subjects.sort()                         # sort in place (alphabetically here)
print("sort     :", subjects)

subjects.reverse()                      # reverse in place
print("reverse  :", subjects)

# A method that *returns* a value rather than modifying in place:
print("count S01:", subjects.count("S01"))

# %% [markdown]
# Notice the difference between the two flavours of methods:
#
# - `subjects.append("S04")` returns nothing — it *modifies the list in place*. Trying to write `result = subjects.append("S04")` would assign `None` to `result`, which is a *very* common beginner trap.
# - `subjects.pop()` and `subjects.count(...)` *return a value* you can capture with `=`.
#
# When in doubt, check the docs, or try it once with ***print(object.method())*** to see what comes back.
#
# Now to **attributes**. Pure-Python lists don't have user-facing attributes, but you'll meet them constantly with the scientific stack. As a tiny preview, a complex number has `.real` and `.imag` attributes:

# %%
# --- Attribute access: no parentheses
z = 1 + 2j
print("z      :", z)
print("z.real :", z.real)   # attribute access — no parentheses!
print("z.imag :", z.imag)

# %% [markdown]
# > **▶ Task 5.1 — Lists in motion.**
# > Start from this list:
# >
# > ```python
# > letters = ["b", "d", "a"]
# > ```
# >
# > Using only the list methods you just met (`.append()`, `.sort()`, `.pop()`, `.reverse()`):
# >
# > 1. Append `"c"` to the list.
# > 2. Sort the list alphabetically.
# > 3. Pop the last element of the list and store it in a variable; print it.
# > 4. Reverse what remains.
# > 5. Print the final list.

# %%
# TODO 5.1 — your code here
letters = ["b", "d", "a"]

letters.append("c")              # TO BE REMOVED
letters.sort()                   # TO BE REMOVED
last_letter = letters.pop()      # TO BE REMOVED
print("popped:", last_letter)    # TO BE REMOVED
letters.reverse()                # TO BE REMOVED
print("final :", letters)        # TO BE REMOVED

# %% [markdown]
# ### 5.3 Dictionaries
#
# A **dictionary** (or `dict`) is an unordered mapping from **keys** to **values**. You write it with **curly braces** and `key: value` pairs separated by commas. Use a dict when you want to *look up* a value by a label.

# %%
# --- Dictionaries
subject_age = {"S01": 24, "S02": 31, "S03": 28}

print(subject_age)
print("age of S02:", subject_age["S02"])
print("subjects  :", list(subject_age.keys()))
print("ages      :", list(subject_age.values()))

# Add or update an entry:
subject_age["S04"] = 22
print(subject_age)

# %% [markdown]
# ### 5.4 Tuples
#
# A **tuple** looks like a list but uses **parentheses** and is **immutable**: once created, its contents cannot be changed. You'll typically meet tuples in two situations: as small fixed bundles of values (e.g. an `(x, y)` coordinate), or as the return value of a function that returns several things at once. For now, just be aware they exist; we'll use them naturally when they come up.
#
# ```python
# point = (0.3, 0.85)   # an (x, y) tuple — point[0] is 0.3, point[1] is 0.85
# ```

# %% [markdown]
# > **▶ Task 5.2 — Build your own collections.**
# > 1. Create a list called `coherences` containing the values `-0.5, -0.15, 0.0, 0.15, 0.5`.
# > 2. Print the length of the list, its first element and its last element.
# > 3. Create a dictionary called `subject_handedness` mapping `"S01"`, `"S02"`, `"S03"` to `"right"`, `"right"`, `"left"`. Print the handedness of subject `S02`.

# %%
# TODO 5.2 — your code here
coherences = [-0.5, -0.15, 0.0, 0.15, 0.5]              # TO BE REMOVED
print("length:", len(coherences))                        # TO BE REMOVED
print("first :", coherences[0])                          # TO BE REMOVED
print("last  :", coherences[-1])                         # TO BE REMOVED

subject_handedness = {"S01": "right", "S02": "right", "S03": "left"}   # TO BE REMOVED
print("S02 handedness:", subject_handedness["S02"])      # TO BE REMOVED

# %% [markdown]
# <a id="section-6"></a>
# ## 6. Conditionals
#
# A **conditional** runs different code depending on whether some condition is true. The basic structure is `if … elif … else`:
#
# ```python
# if condition_1:
#     # runs only if condition_1 is True
# elif condition_2:
#     # runs only if condition_1 was False AND condition_2 is True
# else:
#     # runs if all the above were False
# ```
#
# The `elif` and `else` branches are optional. Indentation matters in Python: the body of each branch must be **indented** (press `tab` on your keyboard to indent).
#
# ### Comparison and logical operators
#
# | Operator | Meaning                  | Example         |
# |----------|--------------------------|-----------------|
# | `==`     | equal to                 | `x == 0`        |
# | `!=`     | not equal to             | `x != 0`        |
# | `<`, `>` | less / greater than      | `x > 0.5`       |
# | `<=`, `>=` | less / greater or equal | `x <= 1`       |
# | `and`    | both must be true        | `0 < x and x < 1` |
# | `or`     | at least one must be true | `x < 0 or x > 1` |
# | `not`    | flips a boolean          | `not x > 0`     |

# %%
# --- Classify a trial by its motion coherence
coherence = 0.05

if abs(coherence) > 0.3:
    difficulty = "easy"
elif abs(coherence) > 0.1:
    difficulty = "medium"
elif coherence == 0:
    difficulty = "ambiguous (no correct answer)"
else:
    difficulty = "hard"

print(f"coherence = {coherence:+.2f}  →  {difficulty}")

# %% [markdown]
# > **▶ Task 6.1 — Side classifier.**
# > Write a small piece of code that, given a value of `coherence`:
# > - prints `"rightward motion"` if `coherence > 0`,
# > - prints `"leftward motion"` if `coherence < 0`,
# > - prints `"no motion (50/50 coin flip)"` if `coherence == 0`.
# >
# > Test it for at least three different values of `coherence`.

# %%
# TODO 6.1 — your code here
coherence = -0.3 # NB: you can change this value to test different cases
if coherence > 0:                                     # TO BE REMOVED
    msg = "rightward motion"                          # TO BE REMOVED
elif coherence < 0:                                   # TO BE REMOVED
    msg = "leftward motion"                           # TO BE REMOVED
else:                                                 # TO BE REMOVED
    msg = "no motion (50/50 coin flip)"               # TO BE REMOVED
print(f"coherence = {coherence:+.2f}  →  {msg}")      # TO BE REMOVED

# %% [markdown]
# <a id="section-7"></a>
# ## 7. Loops
#
# A **loop** repeats the same operation for every item of a sequence.
#
# ### 7.1 `for` loops
#
# The most common loop iterates over a list (or any "iterable"):

# %%
# --- Loop over a list and process each element
subjects = ["S01", "S02", "S03"]
for subj in subjects:
    print(f"now processing subject {subj}")

# %% [markdown]
# Often you want to loop over a range of integers. `range(n)` produces the integers `0, 1, …, n-1`. `range(start, stop)` produces `start, …, stop-1`. `range(start, stop, step)` adds a stride.

# %%
# --- range()
for i in range(5):
    print(i)
print("---")
for i in range(2, 10, 2):    # 2, 4, 6, 8
    print(i)

# %% [markdown]
# Use `enumerate()` when you need **both** the index and the value:

# %%
# --- enumerate()
subjects = ["S01", "S02", "S03"]
for i, subj in enumerate(subjects):
    print(f"#{i}: {subj}")

# %% [markdown]
# Use `zip()` when you need to iterate over two lists in parallel:

# %%
# --- zip()
subjects = ["S01", "S02", "S03"]
ages = [24, 31, 28]
for subj, age in zip(subjects, ages):
    print(f"{subj} is {age} years old.")

# %% [markdown]
# ### 7.2 `while` loops
#
# A `while` loop keeps repeating *as long as* a condition is true. Use it when you don't know in advance how many iterations you need:

# %%
# --- while loop: keep halving until below a threshold
x = 1.0
n_iter = 0
while x > 0.01:
    x = x / 2
    n_iter += 1   # short for: n_iter = n_iter + 1
print(f"reached x = {x:.4f} in {n_iter} iterations")

# %% [markdown]
# > **▶ Task 7.1 — Counting and summing.**
# > Using a `for` loop:
# > 1. Print all the even numbers between 0 and 20 (inclusive).
# > 2. Compute the sum of squares of the integers from 1 to 10 (i.e. $1^2 + 2^2 + \dots + 10^2$). Hint: start with a variable `total = 0` and update it inside the loop.

# %%
# TODO 7.1 — your code here
# 1) even numbers 0..20
for n in range(0, 21, 2):                # TO BE REMOVED
    print(n, end=" ")                    # TO BE REMOVED
print()                                  # TO BE REMOVED

# 2) sum of squares
total = 0                                # TO BE REMOVED
for k in range(1, 11):                   # TO BE REMOVED
    total = total + k ** 2               # TO BE REMOVED
print(f"sum of squares 1..10 = {total}") # TO BE REMOVED

# %% [markdown]
# ### 7.3 Shorthand: list comprehensions
#
# In real Python code (and in any AI-generated snippet you might paste), you will very quickly meet a more compact way to build a list out of a `for` loop: a **list comprehension**. The shape is:
#
# ```
# [ expression   for   variable   in   iterable   if   condition ]
# ```
#
# The `if condition` part is optional. Read it left to right: *"collect every value of `expression`, for every `variable` in `iterable`, keeping only those for which `condition` is true."*
#
# There is nothing magical about it: a comprehension is just a shorter way to write a `for` loop that builds a list. Use it when it makes the code clearer; stick with a regular `for` loop when the body is more than one expression or when the logic is hard to read on a single line.

# %%
# --- Three ways to do the same thing, plus a dict-comprehension bonus

# (1) Classic for-loop building a list
squares = []
for n in range(10):
    squares.append(n ** 2)
print("for-loop      :", squares)

# (2) Equivalent list comprehension
squares = [n ** 2 for n in range(10)]
print("comprehension :", squares)

# (3) Comprehension with a filter: only even squares
even_squares = [n ** 2 for n in range(10) if n % 2 == 0]
print("filtered      :", even_squares)

# (4) Dict comprehensions exist too:same syntax (with key: value pattern)
square_table = {n: n ** 2 for n in range(5)}
print("dict comp     :", square_table)

# %% [markdown]
# <a id="section-8"></a>
# ## 8. Imports and the standard library
#
# Python comes with a large **standard library** of modules that you can use without installing anything. Some highlights:
#
# | Module       | What's inside                                  |
# |--------------|------------------------------------------------|
# | `math`       | mathematical functions (`sqrt`, `log`, `pi`, …) |
# | `random`     | random number generation                       |
# | `statistics` | basic statistics (`mean`, `median`, `stdev`)   |
# | `csv`        | read and write `.csv` files                    |
# | `pathlib`    | manipulate file paths in a portable way        |
#
# To use a module, you `import` it. There are several flavours:

# %%
# --- Three equivalent ways to use math.sqrt
import math
print(math.sqrt(2))

from math import sqrt
print(sqrt(2))

from math import sqrt as square_root  # rename on import
print(square_root(2))

# %% [markdown]
# For the scientific stack (**NumPy**, **pandas**, **matplotlib** etc.) there are *conventional aliases* that everyone uses. You'll see them everywhere from Notebook 2 onwards:
#
# ```python
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# ```
#
# And starting from Notebook 2 we will also import our own helper functions from the course's `src/qmn_utils.py` module:
#
# ```python
# from src.qmn_utils import sigmoid
# ```
#
# We will explain the `src/` folder mechanism when we get there. For now, just know that *anything you can put in a `.py` file, you can import*. That's how big projects stay organized.

# %% [markdown]
# > **▶ Task 8.1 — Use the standard library.**
# > Import the `math` and `statistics` modules and use them to compute and print:
# > 1. The value of $\sqrt{50}$.
# > 2. The natural logarithm of $1000$.
# > 3. The mean and standard deviation of the list `[0.41, 0.55, 0.62, 0.39, 0.48, 0.71]`.

# %%
# TODO 8.1 — your code here
import math                                                    # TO BE REMOVED
import statistics                                              # TO BE REMOVED

print(f"sqrt(50)         = {math.sqrt(50):.4f}")               # TO BE REMOVED
print(f"ln(1000)         = {math.log(1000):.4f}")              # TO BE REMOVED

rts = [0.41, 0.55, 0.62, 0.39, 0.48, 0.71]                     # TO BE REMOVED
print(f"mean RT          = {statistics.mean(rts):.3f} s")      # TO BE REMOVED
print(f"std  RT          = {statistics.stdev(rts):.3f} s")     # TO BE REMOVED

# %% [markdown]
# <a id="section-9"></a>
# ## 9. Reading errors and asking for help
#
# When your code goes wrong, Python prints a **traceback**: a multi-line error message ending with the *most informative* line. The golden rule is:
#
# > **Read the traceback from the bottom up.** The last line tells you *what* went wrong; the lines above tell you *where*.
#
# Let's deliberately cause three common errors and read each one carefully. (Each cell will *fail*, that's the point. Look at the error, then move on.)

# %%
# --- NameError: using a name that was never defined
print(my_undefined_variable)

# %% [markdown]
# `NameError: name 'my_undefined_variable' is not defined` — Python looked for a variable called `my_undefined_variable` in the current kernel and couldn't find one. Either you mistyped the name, or you haven't yet run the cell that defines it. **Most common cause:** running cells out of order. *Restart Kernel → Run All* usually fixes it.

# %%
# --- TypeError: combining incompatible types
"trial " + 3

# %% [markdown]
# `TypeError: can only concatenate str (not "int") to str` — Python's `+` operator means "addition" for numbers and "concatenation" for strings, but the two cannot be mixed. The fix here is to convert the integer to a string first: `"trial " + str(3)`. Even better, use an f-string: `f"trial {3}"`.

# %%
# --- IndexError: asking for a position that doesn't exist
subjects = ["S01", "S02", "S03"]
print(subjects[5])

# %% [markdown]
# `IndexError: list index out of range` — the list has 3 elements (indices 0, 1, 2), so asking for index 5 makes no sense. **Most common cause:** off-by-one. Remember that Python indexing is *0-based*: the last element of a list of length `n` is at index `n - 1` (or, equivalently, `-1`).

# %% [markdown]
# ### Getting help
#
# When you need to know what a function does or which arguments it takes, three quick options inside a notebook:
#
# ```python
# help(math.sqrt)     # full doc in the output
# math.sqrt?          # quick summary (Jupyter shortcut)
# ```
#
# And of course: **read the official docs**. For the standard library, https://docs.python.org/3/library/. For NumPy, pandas, matplotlib, scipy, the project sites all have searchable references and many examples.
#
# > **▶ Task 9.1 — Fix two broken snippets.**
# > The two code cells below each contain a small bug. Read the traceback, identify the problem, and fix the code so that it runs and produces a sensible output. Do **not** silently delete code — fix the bug, then leave a short `# comment` explaining what the bug was.

# %%
# TODO 9.1 (a) — fix the bug
n_trials = 240
mean_rt  = 0.5

# The line below is the BROKEN version (currently commented out so the cell can run).
# Uncomment it, run the cell, read the error, then write a corrected version on
# the line below it.
# print("Subject ran " + n_trials + " trials with mean RT " + mean_rt + " s")

# Your fix here:
print(f"Subject ran {n_trials} trials with mean RT {mean_rt} s")  # TO BE REMOVED

# %%
# TODO 9.1 (b) — fix the bug
rts = [0.41, 0.55, 0.62, 0.39, 0.48]

# BROKEN version (commented out):
# print("last RT:", rts[len(rts)])

# Your fix here:
print("last RT:", rts[-1])  # TO BE REMOVED

# %% [markdown]
# <a id="section-10"></a>
# ## 10. VS Code as your IDE (quick orientation)
#
# VS Code is the editor we recommend for the course. Three small features make the difference between "writing code in a notebook" and "doing data analysis like a pro":
#
# - **Variable explorer.** In a notebook tab, click the `{ }` icon at the top → you get a live panel listing every variable currently alive in the kernel, with type and value. Indispensable for debugging.
# - **Run cell / Run above.** The buttons at the top of every code cell let you run just one cell, or all cells above the current one. Useful when you change something in the middle of a notebook and want to re-run only the affected part.
# - **The integrated terminal.** `Ctrl+\`` opens a terminal *inside* VS Code, already in the project folder. From there you can run `conda activate qmn`, `git status`, `pip install …`, etc., without leaving the editor.
#
# Two more features that we'll meet in later weeks:
#
# - **Breakpoint debugging**: click the red dot to the left of a line in a `.py` file or a notebook cell, then run in debug mode to pause execution there. Useful for understanding what is happening *inside* a function.
# - **Git integration**: the "Source Control" sidebar shows which files you have modified compared to the last commit, and lets you commit & push from inside VS Code.
#
# The TAs will demo these live during the practical. For now: just know they exist.

# %% [markdown]
# <a id="section-11"></a>
# ## 11. Bridge exercise: putting it all together
#
# Time to use everything you have learned so far (i.e. variables, lists, dicts, conditionals, loops) on a very tiny dataset. Below is a small "fake" dataset of 12 trials from a perceptual decision experiment, hard-coded directly into the notebook as a **list of dictionaries**. Each dictionary represents one trial.
#
# In Notebook 2 you will see how to read a real CSV file with thousands of trials and analyse it in a few lines using `pandas` and `numpy`. For now, the goal is just to *feel* what the same kind of analysis looks like when you write every step by hand.

# %%
# --- A tiny dataset of 12 trials, hard-coded as a list of dictionaries
trials = [
    {"subject": "S01", "coherence":  0.50, "response": "right", "correct": True,  "rt_s": 0.42},
    {"subject": "S01", "coherence": -0.30, "response": "left",  "correct": True,  "rt_s": 0.55},
    {"subject": "S01", "coherence":  0.15, "response": "right", "correct": True,  "rt_s": 0.71},
    {"subject": "S01", "coherence": -0.05, "response": "right", "correct": False, "rt_s": 0.89},
    {"subject": "S02", "coherence":  0.30, "response": "right", "correct": True,  "rt_s": 0.39},
    {"subject": "S02", "coherence": -0.50, "response": "left",  "correct": True,  "rt_s": 0.44},
    {"subject": "S02", "coherence":  0.00, "response": "right", "correct": None,  "rt_s": 0.95},
    {"subject": "S02", "coherence": -0.15, "response": "right", "correct": False, "rt_s": 0.78},
    {"subject": "S03", "coherence":  0.50, "response": "right", "correct": True,  "rt_s": 0.38},
    {"subject": "S03", "coherence":  0.05, "response": "left",  "correct": False, "rt_s": 0.66},
    {"subject": "S03", "coherence": -0.30, "response": "left",  "correct": True,  "rt_s": 0.52},
    {"subject": "S03", "coherence":  0.00, "response": "left",  "correct": None,  "rt_s": 0.81},
]

print(f"Total trials       : {len(trials)}")
print(f"Keys of each trial : {list(trials[0].keys())}")
print(f"First trial        : {trials[0]}")

# %% [markdown]
# Let's count how many trials each subject contributed, using a `dict` as a running tally. The pattern is: *start at zero, then for each trial, add one to the right counter*.

# %%
# --- Count trials per subject
trials_per_subject = {}
for trial in trials:
    subj = trial["subject"]
    if subj not in trials_per_subject:
        trials_per_subject[subj] = 0
    trials_per_subject[subj] += 1

for subj, n in trials_per_subject.items():
    print(f"{subj}: {n} trials")

# %% [markdown]
# And the mean reaction time of subject `S01`, computed by hand (sum first, then divide):

# %%
# --- Mean reaction time of subject S01
total_rt = 0.0
n = 0
for trial in trials:
    if trial["subject"] == "S01":
        total_rt += trial["rt_s"]
        n += 1

mean_rt = total_rt / n
print(f"S01: mean RT over {n} trials = {mean_rt:.3f} s")

# %% [markdown]
# > **▶ Task 11.1 — Count correct vs incorrect.**
# > Using a `for` loop on `trials`, count for subject `"S01"`:
# > 1. The number of trials with `correct == True`.
# > 2. The number of trials with `correct == False`.
# > 3. The number of trials with `correct is None` (these are the ambiguous coherence-0 trials).
# >
# > Then compute the **accuracy** as `correct / (correct + incorrect)` and print it as a percentage.

# %%
# TODO 11.1 — your code here
n_correct   = 0
n_incorrect = 0
n_ambig     = 0

for trial in trials:
    if trial["subject"] != "S01":            # TO BE REMOVED
        continue                              # TO BE REMOVED
    if trial["correct"] is True:             # TO BE REMOVED
        n_correct += 1                       # TO BE REMOVED
    elif trial["correct"] is False:          # TO BE REMOVED
        n_incorrect += 1                     # TO BE REMOVED
    else:                                    # TO BE REMOVED
        n_ambig += 1                         # TO BE REMOVED

accuracy = n_correct / (n_correct + n_incorrect)   # TO BE REMOVED
print(f"S01 — correct  : {n_correct}")
print(f"S01 — incorrect: {n_incorrect}")
print(f"S01 — ambiguous: {n_ambig}")
print(f"S01 — accuracy : {accuracy:.1%}")

# %% [markdown]
# **Reflection.** Each of the analyses above took 5–10 lines of Python. They all share the same structure: *loop over the list, maintain counters or accumulators, compute a summary*. As datasets grow from 12 to 12,000 trials, this pattern becomes painful very quickly.
#
# Notebook 2 will introduce **NumPy** and **pandas**, two libraries built exactly to make this pattern disappear. As a preview, the entire "count trials per subject" exercise above shrinks to a single line of `pandas`:
#
# ```python
# df.groupby("subject").size()
# ```
#
# That's what we'll move to from next week onwards. But always remember: under the hood, `pandas` is doing exactly the same loops you just wrote by hand: it's just hidden behind a much friendlier interface.
